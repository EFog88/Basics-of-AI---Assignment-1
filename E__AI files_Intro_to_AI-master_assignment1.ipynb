# %%
import time
import datetime
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
ruter = pd.read_csv('E:/AI files/Intro_to_AI-master/assignment1/Ruter_data.csv', sep=";")#,
  #  names=['TurId', 'Dato', 'Fylke', 'Område', 'Holdeplass_fra',
   #     'Holdeplass til', 'Linjetype', 'Linjefylke', 'Linjenavn', 'Linjeretning',
    #      'Tidspunkt_Faktisk_Ankomst_Holdeplass_Fra',
     #     'Tidspunkt_Faktisk_Avgang_Holdeplass_Fra,',
      #    'Tidspunkt_Planlagt_Ankomst_Holdeplass_Fra',
       #   'Tidspunkt_Planlagt_Avgang_Holdeplass_Fra',
        #  'Kjøretøy_Kapasitet', 'Passasjerer_Ombord'])
ruter.head()
# Out:
#                              TurId        Dato  Fylke Område Kommune  \
# 0  15006-2020-08-10T10:24:00+02:00  10/08/2020  Viken   Vest   Bærum
# 1  15002-2020-08-15T12:54:00+02:00  15/08/2020  Viken   Vest   Bærum
# 2  15004-2020-08-03T09:54:00+02:00  03/08/2020  Viken   Vest   Bærum
# 3  15003-2020-07-27T13:00:00+02:00  27/07/2020  Viken   Vest   Bærum
# 4  15002-2020-08-27T07:15:00+02:00  27/08/2020  Viken   Vest   Bærum
#
#                   Holdeplass_Fra                        Holdeplass_Til  \
# 0                    Nordliveien                             Tjernsmyr
# 1               Nadderud stadion  Bekkestua bussterminal (Plattform C)
# 2               Ringstabekkveien                               Skallum
# 3                      Gruvemyra                              Gullhaug
# 4  Lysaker stasjon (Plattform A)                             Tjernsmyr
#
#   Linjetype Linjefylke Linjenavn  Linjeretning  \
# 0     Lokal      Viken       150             0
# 1     Lokal      Viken       150             0
# 2     Lokal      Viken       150             0
# 3     Lokal      Viken       150             1
# 4     Lokal      Viken       150             1
#
#   Tidspunkt_Faktisk_Ankomst_Holdeplass_Fra  \
# 0                                 10:53:53
# 1                                 13:12:20
# 2                                 10:18:56
# 3                                 13:52:04
# 4                                 07:34:13
#
#   Tidspunkt_Faktisk_Avgang_Holdeplass_Fra  \
# 0                                10:53:59
# 1                                13:12:26
# 2                                10:19:21
# 3                                13:52:26
# 4                                07:34:53
#
#   Tidspunkt_Planlagt_Ankomst_Holdeplass_Fra  \
# 0                                  10:53:00
# 1                                  13:12:00
# 2                                  10:19:00
# 3                                  13:51:00
# 4                                  07:33:00
#
#   Tidspunkt_Planlagt_Avgang_Holdeplass_Fra  Kjøretøy_Kapasitet  \
# 0                                 10:53:00                 112
# 1                                 13:12:00                 112
# 2                                 10:19:00                 112
# 3                                 13:51:00                 112
# 4                                 07:33:00                 112
#
#    Passasjerer_Ombord
# 0                   5
# 1                   5
# 2                   6
# 3                  10
# 4                  10

# %%
Ruter_data = pd.read_csv('E:/AI files/Intro_to_AI-master/assignment1/Ruter_data.csv', sep=";", index_col=0)
Ruter_data.head()
# Out:
#                                        Dato  Fylke Område Kommune  \
# TurId
# 15006-2020-08-10T10:24:00+02:00  10/08/2020  Viken   Vest   Bærum
# 15002-2020-08-15T12:54:00+02:00  15/08/2020  Viken   Vest   Bærum
# 15004-2020-08-03T09:54:00+02:00  03/08/2020  Viken   Vest   Bærum
# 15003-2020-07-27T13:00:00+02:00  27/07/2020  Viken   Vest   Bærum
# 15002-2020-08-27T07:15:00+02:00  27/08/2020  Viken   Vest   Bærum
#
#                                                 Holdeplass_Fra  \
# TurId
# 15006-2020-08-10T10:24:00+02:00                    Nordliveien
# 15002-2020-08-15T12:54:00+02:00                 112                   5
# 15004-2020-08-03T09:54:00+02:00                 112                   6
# 15003-2020-07-27T13:00:00+02:00                 112                  10
# 15002-2020-08-27T07:15:00+02:00                 112                  10

# %%
fig, ax = plt.subplots()

ruter = pd.read_csv('E:/AI files/Intro_to_AI-master/assignment1/Ruter_data.csv', sep=";")

ax.hist=ruter['Kjøretøy_Kapasitet'].value_counts().plot.bar()
ax.set_title('Kjøretøy kapasitet')
ax.set_xlabel('Buss typer per kapasitet')
ax.set_ylabel('Frekvens')
# Out:
# Text(0, 0.5, 'Frekvens')

# %%
ruter = pd.read_csv('E:/AI files/Intro_to_AI-master/assignment1/Ruter_data.csv', sep=";")

ankommetReal = datetime.timedelta = ruter.Tidspunkt_Faktisk_Ankomst_Holdeplass_Fra
ankommetPre = datetime.timedelta = ruter.Tidspunkt_Planlagt_Ankomst_Holdeplass_Fra

onTime = ankommetReal-ankommetPre

ruter.plot.scatter(x=onTime, y= 'Frekvens', title='Ruter dataset')

#fig, ax = plt.subplots()
#ax.hist=ruter['Linjenavn'].value_counts().plot.bar()
#ax.set_title('Kjøretøy frekvens')
#ax.set_xlabel('Buss')
#ax.set_ylabel('Frekvens')

#ruter.plot.hist(subplots=True, layout=(14,14), figsize=(10, 10), bins=20)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\anaconda3\envs\dave3625\lib\site-packages\pandas\core\ops\array_ops.py in na_arithmetic_op(left, right, op, is_cmp)
#     141     try:
# --> 142         result = expressions.evaluate(op, left, right)
#     143     except TypeError:
#
# ~\anaconda3\envs\dave3625\lib\site-packages\pandas\core\computation\expressions.py in evaluate(op, a, b, use_numexpr)
#     229         if use_numexpr:
# --> 230             return _evaluate(op, op_str, a, b)  # type: ignore
#     231     return _evaluate_standard(op, op_str, a, b)
#
# ~\anaconda3\envs\dave3625\lib\site-packages\pandas\core\computation\expressions.py in _evaluate_standard(op, op_str, a, b)
#      67     with np.errstate(all="ignore"):
# ---> 68         return op(a, b)
#      69
#
# TypeError: unsupported operand type(s) for -: 'str' and 'str'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-128-ff375e7200fc> in <module>
#       4 ankommetPre = datetime.timedelta = ruter.Tidspunkt_Planlagt_Ankomst_Holdeplass_Fra
#       5
# ----> 6 onTime = ankommetReal-ankommetPre
#       7
#       8 ruter.plot.scatter(x=onTime, y= 'Frekvens', title='Ruter dataset')
#
# ~\anaconda3\envs\dave3625\lib\site-packages\pandas\core\ops\common.py in new_method(self, other)
#      63         other = item_from_zerodim(other)
#      64
# ---> 65         return method(self, other)
#      66
#      67     return new_method
#
# ~\anaconda3\envs\dave3625\lib\site-packages\pandas\core\ops\__init__.py in wrapper(left, right)
#     341         lvalues = extract_array(left, extract_numpy=True)
#     342         rvalues = extract_array(right, extract_numpy=True)
# --> 343         result = arithmetic_op(lvalues, rvalues, op)
#     344
#     345         return left._construct_result(result, name=res_name)
#
# ~\anaconda3\envs\dave3625\lib\site-packages\pandas\core\ops\array_ops.py in arithmetic_op(left, right, op)
#     187     else:
#     188         with np.errstate(all="ignore"):
# --> 189             res_values = na_arithmetic_op(lvalues, rvalues, op)
#     190
#     191     return res_values
#
# ~\anaconda3\envs\dave3625\lib\site-packages\pandas\core\ops\array_ops.py in na_arithmetic_op(left, right, op, is_cmp)
#     147             #  will handle complex numbers incorrectly, see GH#32047
#     148             raise
# --> 149         result = masked_arith_op(left, right, op)
#     150
#     151     if is_cmp and (is_scalar(result) or result is NotImplemented):
#
# ~\anaconda3\envs\dave3625\lib\site-packages\pandas\core\ops\array_ops.py in masked_arith_op(x, y, op)
#      89         if mask.any():
#      90             with np.errstate(all="ignore"):
# ---> 91                 result[mask] = op(xrav[mask], yrav[mask])
#      92
#      93     else:
#
# TypeError: unsupported operand type(s) for -: 'str' and 'str'

# %%
histogram = ruter['Passasjerer_Ombord'].plot.hist()
#ruter['Passasjerer_Ombord'].plot.axis([0,60,0,2000])
histogram.axis([0,60,0,2750])

#We have chosen to exclude any values below 0 in this vizualisation
# Out:
# (0.0, 60.0, 0.0, 2750.0)

# %%
ax = ruter['Område'].value_counts().sort_index().plot.barh()

# %%
sns.countplot(ruter['Fylke'])
# Out:
# C:\Users\erikf\anaconda3\envs\dave3625\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Fylke', ylabel='count'>
